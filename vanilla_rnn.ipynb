# %%
#This module implments the VANILLA RNN to train an NLP module
#Original source code done by HOUSEZAMETNAT 
#at https://gist.github.com/karpathy/d4dee566867f8291f086
#For slides of basics about Original RNN, refer to: 
# http://cs231n.stanford.edu/slides/2018/cs231n_2018_lecture10.pdf
#Adapted to Python 3

# %%
#Note that this module is implemented entirely using numpy, not TENSORFLOW.
import numpy as np

# %%
#Test an illustration of choosing index by vectors:
a = np.random.randint(0,10,size=(10,1))
print("a:",a)
indx = [1,4,5,7]
print("a[indx]",a[indx])
# Out:
# a: [[8]
#  [3]
#  [3]
#  [8]
#  [2]
#  [0]
#  [0]
#  [2]
#  [2]
#  [4]]
# a[indx] [[3]
#  [2]
#  [0]
#  [2]]

# %%
#Example of exponential broadcasting 
exp = np.exp(a)
print("Exp:",exp)
y = np.exp(a)/np.sum(np.exp(a))
print("y:",y)
del a, indx, exp, y
# Out:
# Exp: [[2.98095799e+03]
#  [2.00855369e+01]
#  [2.00855369e+01]
#  [2.98095799e+03]
#  [7.38905610e+00]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [7.38905610e+00]
#  [7.38905610e+00]
#  [5.45981500e+01]]
# y: [[4.90220418e-01]
#  [3.30307919e-03]
#  [3.30307919e-03]
#  [4.90220418e-01]
#  [1.21513493e-03]
#  [1.64450630e-04]
#  [1.64450630e-04]
#  [1.21513493e-03]
#  [1.21513493e-03]
#  [8.97870015e-03]]

# %%
#Step 1: Import data (must be a text file)
#, then create a list of indices of unique words in the file
data = open('text.txt','r').read().split()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print("The text contains %d unique words!"%(vocab_size))
#Create indices
char_to_ix = {x.lower():i for i,x in enumerate(chars)}
ix_to_char = {i:x.lower() for i,x in enumerate(chars)}
# Out:
# The text contains 83 unique words!

# %%
#Define Hyperparameters 
hidden_size = 100
seq_length = 10
learning_rate = 1e-1

# %%
#Define Model Parameters
#Recall that in vanilla RNN, we have the gate for input, gate for previous info
#Below are the correspoinding weights
Wxh = np.random.randn(hidden_size,vocab_size)*0.01 
Whh = np.random.randn(hidden_size,hidden_size)*0.01
#Note that Wxh and Whh should have the same dimensions because 
#they will be element-wise added later
Why = np.random.randn(vocab_size,hidden_size)*0.01
bh  = np.zeros((hidden_size, 1))
by  = np.zeros((vocab_size, 1))

# %%
def lossFun(inputs, targets, hprev):
    '''
        Input: list of integers corresponding to the indices of words
        Targets: also a list of integer
        Return: loss, gradients and last hidden state
    '''
    xs, hs, ys, ps = {},{},{},{}
    hs[-1] = np.copy(hprev)
    loss = 0
    #FORWARD PASS: through the entire lenngth of the input vector:
    for t in range(len(inputs)): #use t as subsript for 'time'
        xs[t] = np.zeros((vocab_size,1))
        xs[t][inputs[t]] = 1
        #Recall acvitation function: current_cell = tanh(W1*current_input +  W2*previous_state)
        hs[t] = np.tanh(np.dot(Wxh,xs[t]) + np.dot(Whh,hs[t-1]) + bh) #don't forget the bias terms
#         print("Shape of hs:",hs[t].shape)
        ys[t] = np.dot(Why,hs[t]) + by
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#         print("Shape of probability output vector",ps[t].shape) #Should be (vocab_size,1)
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
    #BACKWARD PASS: upgrade the gradient 
    #The Gradients should have the same shape
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
    '''Randomly sample from the network sometimes. 
    '''
    x = np.zeros((vocab_size,1))
    x[seed_ix] = 1
    ixes = []
    assert Wxh.shape[1] == x.shape[0], "Wxh vs x shape mismatched {} vs {}".format(Wxh.shape, x.shape)
    assert Whh.shape[1] == h.shape[0], "Whh vs h shape mismatched {} vs {}".format(Whh.shape, h.shape)
    #Loop through n
    for t in range(n):
        h = np.tanh(np.dot(Wxh,x) + np.dot(Whh,h) + bh)
#         print("h shape {}".format(h.shape))
        y = np.dot(Why,h) + by
        #Find the probability
        p = np.exp(y)/np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %% [markdown]
# ## Implement the run through data

# %%
n,p = 0,0
#Set up the memory for AdamGrad
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) 
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
counter = 0
while n < 1e4:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n==0:
        hprev = np.zeros((hidden_size,1))
        p = 0
    inputs = [char_to_ix[ch.lower()] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch.lower()] for ch in data[p+1:p+seq_length+1]]
#     print("Inputs",inputs)
#     print("Targets",targets) 
    # Sample from the model now and then
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 100)
        txt = ' '.join(ix_to_char[ix] for ix in sample_ix)#Add a random word in ?
        print('----\n %s \n----'% (txt, ))
    counter+=1 #Added for counter later

    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 100 == 0: 
        print('iter %d, loss: %f'% (n, smooth_loss)) # print progress

    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                            [dWxh, dWhh, dWhy, dbh, dby], 
                            [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# ----
#  took i'll anymore more to because picture you knees into again heard my me go (anymore, accidentally best just more again swearing into hoping song, yours" ever places know ever off anymore) not time just never you're name and i've (love, mind mean mean am i'd accidentally picture one yours" anymore hoping took you "i'm off swearing off your hear i'll bad? to mind on again time off took i'll so wander we slipped anymore i've feel because (love, places anymore, knees well, accidentally anymore) "i'm you hoping last it (anymore, accidentally last so feel time swearing name i'm insecure
# ----
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# iter 0, loss: 44.188411
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# ----
#  swearing am missing still swearing i'll when say accidentally you myself do because mean love you i'm last uh yours" swearing ever love slipped change missing my i'd it accidentally because would not on i'd mind so had? i would i'm not best yours" not i anymore picture you're love and do anymore, love am i'm me am i'd had? yours" your you would i'm on mean phone places love say would that on (love, time say you're hear because yours" said my the makes i anything never anymore lying time anymore, mean run makes slipped change mean places hoping
# ----
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# iter 100, loss: 45.237134
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# ----
#  you just feel to doesn't anymore anything i'd ever would it bad? anymore) because took (anymore, and and 'round i i took and ever anymore) said would i'll 'round i the i am uh say 'round anymore) i 'round uh just the that that never anymore, your go time just because that i'm you're one and it slipped and (anymore, 'round your i i you're (anymore, took again i 'round well, phone i know (anymore, bad? took i picture the not the because time would last just because just would just because am bad? mind i'm last (anymore, (anymore, anymore)
# ----
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# iter 200, loss: 45.225195
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# ...
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# ----
#  feel on my uh and best your you change and swearing say say change more because i know i'll never ever uh the best and would do am change said your doesn't know i'll never ever feel the same doesn't mean i just not missing anything i'm on i'd ever and the when i know i'll i've ever myself the best doesn't mind i love you say ever yours" just because mind uh doesn't say i'll never again same you best uh that one slipped because uh picture uh not the i'll i've i'll heard name best i've am i'm
# ----
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# iter 500, loss: 39.693566
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# Shape of hs: (100, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-69c4e7f0f36d> in <module>()
#      21     counter+=1 #Added for counter later
#      22
# ---> 23     loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      24     smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      25     if n % 100 == 0:
#
# <ipython-input-7-56dd081f0efc> in lossFun(inputs, targets, hprev)
#      34         dWxh += np.dot(dhraw, xs[t].T)
#      35         dWhh += np.dot(dhraw, hs[t-1].T)
# ---> 36         dhnext = np.dot(Whh.T, dhraw)
#      37     return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]
#
# KeyboardInterrupt:
