# %% [markdown]
# # Introduction
# This module implements basic LSTM architecture by building up on the implementation of vanilla RNN

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %load_ext autoreload
# %matplotlib inline

# %% [markdown]
# ## Set up and Read Data

# %%
data = open('text.txt','r').read().split()
vocab = list(set(data))
vocab_size = len(vocab)
print("There are %d uniques vocabs."% len(vocab))
#Create dictionary of indices for vocabs
char_to_indx = {char.lower():indx for indx,char in enumerate(vocab)}
indx_to_char = {indx:char.lower() for indx,char in enumerate(vocab)}
# Out:
# There are 83 uniques vocabs.

# %% [markdown]
# ## Set up Parameters

# %%
num_hidden = 200
seq_length = 20 #Equivalent to time step
learning_rate = 2e-1
#Remember that the input vector has the length of the sequence
#And in LSTM, the vectors are "stacked" together at each step
z_size     = num_hidden + vocab_size

# %% [markdown]
# ## Define Placeholders

# %%
#Recall that in LSTM, the general equation for each cell/timestep is:
# (i f o g).T = (sigmoid =sigmoid sigmoid tanh).T*W_matrix*(ht-1 xt).T
# Backprop must go through one of each gate, so we need a weight matrix for each of them
Wi = np.random.randn(num_hidden, z_size)*0.1
bi = np.zeros((num_hidden, 1))

Wf = np.random.randn(num_hidden, z_size)*0.1
bf = np.zeros((num_hidden, 1))

Wo = np.random.randn(num_hidden, z_size)*0.1
bo = np.zeros((num_hidden, 1))

Wg = np.random.randn(num_hidden, z_size)*0.1
bg = np.zeros((num_hidden, 1))

#Observe the dimensions of the matrices follow intuition by matrix multiplication rule
Wy = np.random.randn(vocab_size,num_hidden)*0.1
by = np.zeros((vocab_size, 1))

# %%
#Define gradients 
dWi = np.zeros_like(Wi)
dbi = np.zeros_like(bi)

dWf = np.zeros_like(Wf)
dbf = np.zeros_like(bf)

dWo = np.zeros_like(Wo)
dbo = np.zeros_like(bo)

dWg = np.zeros_like(Wg)
dbg = np.zeros_like(bg)

dWy = np.zeros_like(Wy)
dby = np.zeros_like(by)

# %%
#Helpfer functions
def sigmoid(x): 
    '''Assume that x is a a vector of dimension (some_num,1)'''
    return 1/(1 + np.exp(-x))

def dsigmoid(dx):
    return dx*(1-dx)

def softmax(x):
    '''Assume that x is a a vector of dimension (some_num,1)'''
    return np.exp(x)/np.sum(np.exp(x))

def dtanh(dx):
    return 1-dx*dx

# %%
def forward(inputs, hprev, cprev):
    '''
        Inputs should be a vector/array of that correspond to the indices
        *Note: compare this with the parameters of VRNN to see the difference in architecture
    '''
    #Test dimensions before running 
    assert inputs.shape == (vocab_size,1)
    assert hprev.shape  == (num_hidden,1)
    assert cprev.shape  == (num_hidden,1)
    z = np.row_stack([hprev, inputs])
    f = sigmoid(np.dot(Wf,z) + bf)
    
    i = sigmoid(np.dot(Wi,z) + bi)
    
    g = np.tanh(np.dot(Wg,z) + bg) #Should be equivalent to C_bar in the source code, and also tanh
   
    c_t = (f*cprev) + (i*g)
    
    o = sigmoid(np.dot(Wo,z) + bo)
    h_t = o*np.tanh(c_t)
    
    #Output probability of this time cell
    y = np.dot(Wy,h_t) + by
    p = softmax(y)
    
    return z,i,f,o,g,c_t,h_t,y,p

# %%
def backward(targets, dhnext, dcnext, cprev, z, i, f, o, g, c_t, h_t, y, p):
    '''Targets should be a vector of intergers
    Note that since the forward pass invoves h and c, the parameters here
    involve dhnext and dcnext
    '''
    global dWi, dWf, dWo, dWg, dWy
    global dbi, dbf, dbo, dbg, dby
    
    #Verify dimension compatibility 
    assert z.shape == (z_size, 1)
    assert y.shape == (vocab_size,1)
    assert p.shape == (vocab_size,1)
    
    for item in [i,f,o,g,c_t,h_t]: 
        assert item.shape == (num_hidden,1), "Shape is {} but not {}".format(item.shape, (num_hidden,1))
    
    dy = np.copy(p)
    dy[targets] -= 1
    dWy += np.dot(dy,h_t.T)
    dby += dy
    
    dh = np.dot(Wy.T, dy)
    dh += dhnext
    
    do = dh*np.tanh(c_t)
    do = dsigmoid(c_t) * do
    #Update dWo
    dWo += np.dot(do, z.T)
    dbo += do
    #Update dWg
    dc = np.copy(dcnext)
    dc += dh * o * dtanh(np.tanh(c_t))
    dg = dc * i
    dg = dg * dtanh(g)#Note: equivalent to dg
    dWg += np.dot(dg, z.T)
    dbg += dg
    #Update dWi
    di = dc * g 
    di = di * dsigmoid(i)
    dWi += np.dot(di, z.T)
    dbi += di
    #Update dWf
    df = dc * cprev
    df = df * dsigmoid(f)
    dWf += np.dot(df, z.T)
    dbf += df
    #update dz (remember that z is also one of the input)
    dz = np.dot(Wi.T,di) + np.dot(Wf.T,df) + np.dot(Wo.T,do) + np.dot(Wg.T,dg)
    dhprev = dz[:num_hidden,:] #Gradient for h should only have dimension of h
    dcprev  = dc * f
    return dhprev, dcprev

# %%
#TEST CODE
test_input = np.zeros((vocab_size,1))
test_input[np.random.randint(0,vocab_size-1,size=1)] = 1
test_hprev = np.random.randn(num_hidden,1)*1e-2
test_cprev = np.random.randn(num_hidden,1)*1e-2

# %%
#Test FORWARD
a,b,c,d,e,f,g,h,i =forward(test_input, test_hprev, test_cprev)
print("a:({}), b:({}), c:({}),d:({}),e:({});,f:({}),g:({}),h:({}),i:({}))".format(a.shape,b.shape,c.shape
                                                                   ,d.shape,e.shape,f.shape
                                                                  ,g.shape,h.shape, i.shape))
# Out:
# a:((283, 1)), b:((200, 1)), c:((200, 1)),d:((200, 1)),e:((200, 1));,f:((200, 1)),g:((200, 1)),h:((83, 1)),i:((83, 1)))

# %%
#Test BACKWARD
m, n = backward(5, test_hprev, test_cprev, test_cprev, a,b,c,d,e,f,g,h,i)
print("m shape: ({}), n shape: ({})".format(m.shape, n.shape))
del a,b,c,d,e,f,g,h,i,m,n
# Out:
# m shape: ((200, 1)), n shape: ((200, 1))

# %%
def one_pass(inputs, targets, hprev, cprev):
    '''
    Perform one forward step and one backward step through the sequence
    '''
    x_s, z_s, i_s, f_s, o_s, g_s, c_s, h_s, t_s, y_s, p_s =  {},{},{},{},{},{},{},{},{},{},{} 
    h_s[-1] = hprev
    c_s[-1] = cprev
    loss = 0
    #FORWARD pass
    for t in range(len(inputs)): 
        x_s[t] = np.zeros((vocab_size,1))
        x_s[t][inputs[t]] = 1
        z_s[t], i_s[t], f_s[t], o_s[t], g_s[t], c_s[t], h_s[t], y_s[t], p_s[t]  \
            = forward(x_s[t], h_s[t-1], c_s[t-1])
        loss += -np.log(p_s[t][targets[t],0]) 
    #BACKWARD pass
    #Reset all gradietn to 0 for the run
    for dparam in [dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dby, dbg]:
        dparam.fill(0)
        
    dhnext = np.zeros_like(h_s[0])
    dcnext = np.zeros_like(c_s[0])
    for t in reversed(range(len(inputs))):
        dhnext, dcnext = backward(targets=targets[t],dhnext=dhnext,dcnext=dcnext, cprev=c_s[t-1], \
                                 z=z_s[t], i=i_s[t],f=f_s[t],o=o_s[t],g=g_s[t],c_t=c_s[t],h_t=h_s[t],\
                                 y=y_s[t],p=p_s[t])
    
    #Perform gradient clipping
    for dparam in [dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dby, dbg]:
        np.clip(dparam,-1,1,out=dparam)

    return loss, h_s[len(inputs) - 1], c_s[len(inputs) - 1]

# %%
def sample(hprev, cprev, seed_ix, sentence_length):
    '''Randomly sample from the network sometimes. 
    '''
    x = np.zeros((vocab_size,1))
    x[seed_ix] = 1
    indices = []
    
    h = hprev
    c = cprev
    
    #Loop through n time steps
    for t in range(sentence_length):
        _, _, _, _, _, _, _, _, p = forward(inputs=x, hprev=h, cprev=c)
        idx = np.random.choice(range(vocab_size),p=p.ravel())#choose a random index in the output
        x = np.zeros((vocab_size,1))
        x[idx] = 1
        indices.append(idx)
    return indices

# %%
#Create memory for AdamGrad
mWi = np.zeros_like(Wi)
mWf = np.zeros_like(Wf)
mWo = np.zeros_like(Wo)
mWg = np.zeros_like(Wg)
mWy = np.zeros_like(Wy)

mbi = np.zeros_like(bi)
mbf = np.zeros_like(bf)
mbo = np.zeros_like(bo)
mbg = np.zeros_like(bg)
mby = np.zeros_like(by)

# %%
n, p = 0, 0
smooth_loss = -np.log(1.0/vocab_size)*seq_length
while n < 1e4: 
    try: 
        if p + seq_length + 1 >= len(data) or n==0:
            hprev = np.zeros((num_hidden,1))
            cprev = np.zeros((num_hidden,1))
            p = 0 
        
        inputs = [char_to_indx[ch.lower()] for ch in data[p:p+seq_length]]
        targets = [char_to_indx[ch.lower()] for ch in data[p+1:p+seq_length+1]]
        
        loss, hprev, cprev = one_pass(inputs, targets, hprev, cprev)
        smooth_loss = smooth_loss * 0.999 + loss * 0.001
        
        if n % 1e2 == 0:
            sample_ix = sample(hprev, cprev, inputs[0], 50)
            txt = ' '.join(indx_to_char[ix] for ix in sample_ix)#Add the next one
            print('----\n %s \n----'% (txt, ))

        
        if n% 1e2 == 0:
            print('iter %d, loss: %f'% (n, smooth_loss)) # print progress
            
        # perform parameter update with Adagrad
        for param, dparam, mem in zip([Wi, Wf, Wo, Wg, Wy, bi, bf, bo, bg, by], 
                            [dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dbg, dby], 
                            [mWi, mWf, mWo, mWg, mWy, mbi, mbf, mbo, mbg, mby]):
            mem += dparam * dparam
            param += -(learning_rate * dparam / np.sqrt(mem + 1e-8)) # adamgrad update
            
        p+=seq_length    
        n+=1
    except KeyboardInterrupt:
        print("User terminated process")
        break
# Out:
# ----
#  places i've (love, one slipped ever the uh and feel say swearing 'round just not anymore) picture picture knees last (love, wander we slipped one (love, insecure it phone it doesn't off uh do hear and would ever and on anymore, i'm hear had? anything said your i've makes doesn't
# ----
# iter 0, loss: 88.376784
# ----
#  because because because i that i'm one still because just because because i i because just just just your i anything i yours" i just i i because that because because i run i your just feel ever just just best because when because i'm because 'round because the because
# ----
# iter 100, loss: 91.514281
# ----
#  last anymore am so doesn't anymore, you so just best you just am never you doesn't my my know just ever just doesn't bad? never say just just the "i'm just knees just know because the that just go just just mind we am the i your say lying doesn't
# ----
# iter 200, loss: 91.654930
# ----
#  when never well, anymore you myself because just because again run never because because ever i love you anymore you love ever never because because because hear i never because mean song, because change because slipped say into feel because because and because anymore again say i just because say
# ----
# iter 300, loss: 91.415801
# ----
#  would anymore love anything again again (love, song, i'd anything never myself know accidentally you ever one again anything never again so again your again love into best again know anything know so same i'll so love uh song, the myself when we know on i again when myself to
# ----
# iter 400, loss: 90.695457
# ----
#  heard mean doesn't mean feel i i mean mean not heard doesn't my i mean heard am i love) doesn't ever insecure heard i mean myself wander to mean uh hear doesn't i'll you're mean i when well, i the ever i love and when hear know ever i doesn't
# ----
# iter 500, loss: 90.103653
# ----
#  never to to to again i feel say myself again i love and not you heard "i'm my love ever i heard just to just never into say myself heard myself had? i'll knees to had? feel love uh had? i'd best because slipped doesn't just to to so change
# ----
# iter 600, loss: 89.214776
# ----
#  because myself to slipped not best missing missing accidentally doesn't because you i'll heard doesn't not you i'm best change doesn't on ever mean i'm i (love, more to myself took know to i've hear say myself say accidentally ever i've not again just mean anymore, would missing because ever
# ----
# iter 700, loss: 88.350491
# ----
#  to "i'm love never lying i i'm slipped you love you and to i i'll said my lying mean love to and know know i lying i'll i'll am i'll never not lying i i lying i just uh my i'll run i i change to never never i anymore
# ----
# iter 800, loss: 87.331367
# ----
#  go to same bad? i'll my doesn't ever had? i say anything anymore that know bad? had? say feel mind i to i myself i well, say i hear lying know song, bad? mean i hear into you myself when again to you myself not you off not i've yours"
# ----
# iter 900, loss: 85.978234
# ----
#  i'm you heard again again bad? ever do love) again say uh love) say you're anymore, love) again never picture more i'd again love) and off into when myself i'm again same you it picture i off insecure on it song, me feel when myself i uh makes i do
# ----
# iter 1000, loss: 84.588098
# ----
#  insecure i'll i'll missing you same you i'm the doesn't would i swearing i doesn't i'm because say i so because time "i'm i i i on one makes swearing i so ever insecure you do accidentally off missing say love you hear you're that same you doesn't i'm that
# ----
# iter 1100, loss: 83.508991
# ----
#  one myself just am anything when because one and am that and i'm that time "i'm know my you (love, when when when i my anymore when anymore say say just just am anything i said that never so that anymore feel when ever anymore just know and never i
# ----
# iter 1200, loss: 82.387336
# ----
#  doesn't again again knees change and i'm my mind anything you're best i ever name name the change because you're said do i'll change say mean on and am name again when you uh i'm do doesn't (love, (love, anymore, more said mean you my never love feel my knees
# ----
# iter 1300, loss: 81.266715
# ----
#  i wander slipped i know wander love i on missing myself i i same you insecure one you i've i know i'd because well, that the last missing mind know never you same you took phone hear not picture 'round you i'd i know i run phone i lying off
# ----
# iter 1400, loss: 80.116558
# ----
#  i you you anymore you "i'm you say hear "i'm anymore, you're one you makes know just you anymore just bad? same love) anymore love) know your heard "i'm you hoping because doesn't well, to feel you you know i love) anymore that (love, and know anything to feel you
# ----
# iter 1500, loss: 79.545493
# ----
#  say the just ever off lying the never mean you when i when on lying when i am (love, anymore would slipped took we i'm never name i never that ever i lying ever said again picture go and i name i again myself you ever again your you myself
# ----
# iter 1600, loss: 78.659945
# ----
#  and into am you again say change i've when bad? do i i i love i same you so i same the ever to just because uh again i ever you're love i heard slipped ever because ever you change when to say missing again myself lying when and heard
# ----
# iter 1700, loss: 77.818894
# ----
#  when change my am i so change phone and so that lying i same would never i'm my love and say change mean picture my mind just love and just i'd "i'm and love had? feel i'd i'd would the say makes am mean would not anymore feel just and
# ----
# iter 1800, loss: 76.868876
# ----
#  i've your the i i've change on i never my knees on i'd because my you the best you anymore, (love, you anymore myself not to never knees am best i last missing the your never you am ever uh the it the love the i the one you anymore
# ----
# iter 1900, loss: 75.827451
# ----
#  you anymore yours" i same bad? anymore when you same mean the anymore again love you same you hear again when again again you're when because makes again again again again when you're know accidentally again myself again again accidentally i'll when just because into to the love again know
# ----
# iter 2000, loss: 74.781952
# ----
#  had? missing i me ever anymore picture bad? hear yours" never off ever do say my mean just would makes "i'm yours" yours" uh that hoping knees not you not you say hear off say (love, "i'm i mean my change into "i'm you wander had? that and doesn't lying
# ----
# iter 2100, loss: 73.801455
# ----
#  because my i so to places because my off still you just because time off so i mean to i i because hoping go anything off doesn't the the lying you my never on you into would it mean doesn't i hoping 'round places hear 'round phone into you would
# ----
# iter 2200, loss: 73.203526
# ----
#  ever last my best never i said i'll i'll never (love, am love) am into on not i am and best my am i you anymore, am doesn't to you not on hear just time "i'm i again when "i'm i i'll do to hoping bad? my you would i've
# ----
# iter 2300, loss: 72.818602
# ----
#  i when i mean mean i'm your your picture feel "i'm feel had? i'm doesn't myself feel on feel know know doesn't anymore on say love) am i same just because feel that you i i'm i you know my swearing anymore took feel i feel that you anymore love)
# ----
# iter 2400, loss: 71.941749
# ----
#  i'll i'll i'll never said still well, i'll ever same again mean your i'll i'll i'll doesn't insecure doesn't well, slipped your to know i'll i'll know anymore, time picture you anymore, you're that still i would my took the one do same that still my you into accidentally picture
# ----
# iter 2500, loss: 71.655076
# ----
#  just because i i i ever again when change because said still on we do mean well, i'll feel and feel knees to say again your to you're you're to i again said never would on ever run my on when that picture the know makes i'll well, never you
# ----
# iter 2600, loss: 70.942272
# ----
#  say swearing time bad? say swearing to your last time doesn't i insecure took to i name last never anymore to am time to uh time bad? just because to myself feel say say lying i'm missing say last song, time to i've lying love best had? doesn't last insecure
# ----
# iter 2700, loss: 69.862188
# ----
#  lying i the just doesn't hear love hear i'll i doesn't same again anymore swearing mean i hear myself lying i i'm love i i'm i say you love that feel i heard i'll doesn't i lying lying you know and swearing love lying i best i mean i again
# ----
# iter 2800, loss: 68.966404
# ----
#  the ever bad? name again i'm you the just am because doesn't would you never missing well, doesn't never say ever on swearing i'll i'll because not change i'll lying say i say say on swearing you doesn't change because anything know and knees again when go say not you're
# ----
# iter 2900, loss: 68.670031
# ----
#  because you never love the anything mind you're ever when ever the never myself lying to just because song, ever because myself again hear uh know doesn't anything you on you i ever when i'm on myself again change (love, again best more hoping more insecure am you you said
# ----
# iter 3000, loss: 68.310495
# ----
#  because heard you you i am do change that say swearing that i'm you're the you accidentally i say you say bad? and i'd "i'm yours" yours" change to to when i i swearing "i'm bad? say to mean to i'll you had? yours" you doesn't to you so you
# ----
# iter 3100, loss: 67.691264
# ----
#  my that because insecure because i'm bad? just because i to just because you're missing anything best i ever just because i say am took you're heard that i ever say hear say i i would anything to say i say anything my you know i i've the heard change
# ----
# iter 3200, loss: 67.071025
# ----
#  the we would because last hoping swearing run hoping because do because the i've go i'll yours" run into and your last change you because because song, last last time your you the you that you said your never one would and you you your (love, the hoping you would
# ----
# iter 3300, loss: 66.093233
# ----
#  hear hear insecure i say am anymore mean missing i i and not you're swearing hear so would hear lying i anymore had? feel mean when just my the know i i makes swearing hear i name so go know ever mean hear myself swearing so lying hear anymore your
# ----
# iter 3400, loss: 65.766001
# ----
#  slipped love) places on phone i'll slipped off anymore, took again am swearing took never i say go slipped doesn't i am myself the lying anything to "i'm to say ever doesn't the would you're you're picture off lying mean would places places (love, i'm do you're still that am
# ----
# iter 3500, loss: 65.269004
# ----
#  doesn't not bad? because i know am doesn't so same i'll same you said your you ever i'll i'm you're say you're say yours" just ever because more not that lying makes lying my i i'm because the ever you anymore uh just ever mean anymore doesn't missing mean i
# ----
# iter 3600, loss: 65.029662
# ----
#  anymore hear i swearing the you're same am that do say you doesn't missing when again doesn't i'm you're i again lying makes i say feel that just doesn't that do am feel you're i'll me say bad? i'm so i that again again so that hear i song, just
# ----
# iter 3700, loss: 64.733841
# ----
#  best i'll to when doesn't am mean knees i've say not the not and i (love, you you the i'm feel i say feel ever say you missing that ever just just not the same mean anymore, to myself ever again hear and i've i've doesn't am knees anymore, i've
# ----
# iter 3800, loss: 64.496132
# ----
#  i i best lying lying i am hear do so phone again "i'm song, because so love bad? i you say i'll i i love) best just more love the love because when i because you're just because would do doesn't anymore do i because same i am i swearing
# ----
# iter 3900, loss: 64.456938
# ----
#  knees knees because myself missing my knees hear off i say doesn't myself that say (love, to do heard that said missing you that that my you anything knees knees knees "i'm i'll again doesn't because say not i "i'm best phone would on would am on you would i
# ----
# iter 4000, loss: 64.015638
# ----
#  you're know the same ever had? ever missing my knees i the go because know doesn't hear i the "i'm yours" "i'm you yours" when change anymore i'm again last time you doesn't am "i'm yours" ever again best mean mean on know so you anymore, again i say yours"
# ----
# iter 4100, loss: 63.406460
# ----
#  i'll i'll ever love would more same mean you because would i'll i've mean the love because mean doesn't lying love i'll i'll i'll just would i'll bad? hoping change know still mean i've missing mean more my i'll i'll i'll just because same am doesn't ever well, say you
# ----
# iter 4200, loss: 63.013637
# ----
#  lying do do best mean that you're am to myself to am me that say when am on my run into the just would name and to well, your well, am i well, song, i just because i to say uh slipped me still and would we i had? feel
# ----
# iter 4300, loss: 63.083391
# ----
#  that i've just am same never mean i insecure your still your myself just more i not your love mean ever mean "i'm mean i am mean i doesn't best i've say just said insecure to mean myself "i'm just i'm again i've say am heard it i'd do accidentally
# ----
# iter 4400, loss: 62.231345
# ----
#  you so feel mean feel i'll bad? i go would knees doesn't not i'd on am hear i not had? and you and do anything to myself i i my go anything well, to myself mean best "i'm myself and just because i just because say ever never just because
# ----
# iter 4500, loss: 61.061087
# ----
#  just phone so i'd phone would on i anymore love same mean the so picture ever say say change love one hear you one last time hear myself so yours" song, hoping you're just mean had? anymore, love just because love best again so off ever the same accidentally love
# ----
# iter 4600, loss: 59.514004
# ----
#  just mean doesn't feel so you so i'll feel know i'm feel and swearing when say to because i doesn't had? feel because feel feel anything i've i'll bad? best when missing you so you love i'm on yours" had? am the on anything just the anymore mean i would
# ----
# iter 4700, loss: 57.864155
# ----
#  doesn't doesn't insecure bad? feel never ever feel again best again mean again to myself that that not feel ever doesn't feel never doesn't never mean feel feel never mean the anymore, you so bad? ever bad? i've do i not the feel the that and i'd you so the
# ----
# iter 4800, loss: 56.261839
# ----
#  missing and to doesn't (love, your your would you say to myself not because do knees not missing not feel had? i'll so again not say hear swearing and me and my you best you am i your i'm again when and you anymore, you so to i song, i'm
# ----
# iter 4900, loss: 54.790792
# ----
#  anymore and anything and i'm so to would change myself i'd change knees and hoping anymore would change anything run into would and hear into we said slipped makes slipped name mind hoping would change anything and anything one last into anything do anymore ever doesn't would change anything and
# ----
# iter 5000, loss: 53.595663
# ----
#  slipped your well, your picture took i just just on i the same i lying and i'd i just because the do swearing i'd do just i say change well, it it you my that i'm to do well, i'm i never the swearing well, your i'll name name to
# ----
# iter 5100, loss: 52.732173
# ----
#  never you so phone had? myself i lying you i i i myself i've to again when bad? am just because i my mind best i've i ever say "i'm took to swearing knees and that missing i say "i'm knees i would that so uh you're i ever had?
# ----
# iter 5200, loss: 51.780177
# ----
#  do and you so knees phone anything to know i'll i'll i know i'll am feel you know i'll feel feel i'll i'll knees and on my do my yours" more had? i so doesn't i'd knees and love) change anything on best know i'll had? and to accidentally am
# ----
# iter 5300, loss: 51.309842
# ----
#  lying the missing mean doesn't the mean doesn't again when you doesn't again when i am lying say on anymore, doesn't the doesn't mean i'll i'm again never doesn't mean that lying lying again mean never doesn't mean doesn't mean doesn't doesn't doesn't mean doesn't am i i doesn't mean
# ----
# iter 5400, loss: 50.064536
# ----
#  change just not anything myself myself am i lying just because your my just your insecure run into just because i anymore your hoping run into run into run into do i picture change uh uh uh uh uh phone just that anymore, that lying you're run into love) into
# ----
# iter 5500, loss: 49.041556
# ----
#  know i'll feel you one the anything the swearing the feel you so on makes say name slipped well, name the say know doesn't you say i've lying myself say the not lying ever doesn't lying not you makes to myself you anymore, had? say know i'll again myself to
# ----
# iter 5600, loss: 48.034887
# ----
#  uh uh not just the makes just because makes i and insecure said we uh uh uh knees insecure i uh uh uh uh uh me and into uh uh and said insecure insecure i've would uh uh uh knees just run into uh not your me insecure am i
# ----
# iter 5700, loss: 47.061834
# ----
#  am i'm doesn't ever song, i'm am am just never ever i'll missing doesn't missing say i've i'm "i'm and never i'm lying my yours" i'm missing my had? still the i'm doesn't never the just because ever my hear just say lying i'm just i'm had? ever never say
# ----
# iter 5800, loss: 46.074324
# ----
#  just because i would said the know i mean you so i to not i i i my i i know i'll love on i ever ever doesn't to i you so that would the i i 'round said the feel mean again i accidentally i i i know i
# ----
# iter 5900, loss: 44.969763
# ----
#  know ever ever just because to when again say do when never doesn't i myself on to because say me you ever when i when doesn't mean swearing again because yours" ever ever my i'd when you do anything best and not missing best not when ever i when am
# ----
# iter 6000, loss: 44.055002
# ----
#  anymore, that same never heard the i myself "i'm anymore took and you're love that "i'm my the change the not love not not the the same to love ever know change not you're i'd love) love the the love to i'm love) love) anymore love ever the same mean
# ----
# iter 6100, loss: 43.585260
# ----
#  swearing change am i am would you're my makes you that i'm to knees would knees change just because insecure slipped to myself change my you song, because again knees the love to anything you heard took not the anything you love the lying to i you feel you anymore
# ----
# iter 6200, loss: 43.368885
# ----
#  i uh you knees the again you're i'd love) phone would you're i time into go you the "i'm off say uh your into the hoping you doesn't again when phone i'll (love, last into i my you when go i anything not am i insecure you and you phone
# ----
# iter 6300, loss: 43.183051
# ----
#  i say you so again myself again i lying best to i my on on anymore doesn't you anymore best go same your again my mind say "i'm the when just because had? into phone mean yours" i'd to mind i just off i just swearing you're am bad? best
# ----
# iter 6400, loss: 43.854115
# ----
#  had? myself again just because so your missing say i've lying you say because i took to hear you would uh love myself you i'm that to i myself you do song, more say the know i'll mean i hear because i'm the my and missing say you ever to
# ----
# iter 6500, loss: 44.452370
# ----
#  because on you swearing change anymore, just because i not and i just i accidentally i i you i i i knees i just just i've to i feel when am i'll i never insecure i i i not anything i've lying i'll bad? just to i would last am
# ----
# iter 6600, loss: 45.094749
# ----
#  myself you you're time last you're you're anymore, i ever mind yours" i'm your just when bad? anymore, song, name you that "i'm you that time we run hoping you say "i'm change "i'm you're same doesn't i'm you anymore you said missing myself you you i'd uh uh uh
# ----
# iter 6700, loss: 45.589952
# ----
#  you myself my it my uh anything missing your doesn't ever feel ever would and love i'm into you're i've not and said your when i just because when not you're still my phone my anymore, doesn't same same doesn't again am lying you're myself same the lying my my
# ----
# iter 6800, loss: 46.219083
# ----
#  you i'm when missing myself you swearing best missing am missing more best you say and never best i've the say because not just because am i just because i i'm and missing when hear i to my know i'll you i'd knees i i'd because it i hoping your
# ----
# iter 6900, loss: 46.659611
# ----
#  lying the not love lying to uh again you know the same lying to i i lying again picture heard when am am i ever had? i places phone lying that that swearing love you anymore accidentally slipped name song, anymore makes bad? my mind me i myself i best
# ----
# iter 7000, loss: 46.846249
# ----
#  time uh do and yours" time i phone you say missing i had? when because feel yours" missing had? took just because the not uh that swearing you're anything to ever had? say i places just because the best because that more yours" not just because would mind just because
# ----
# iter 7100, loss: 46.901127
# ----
#  the song, slipped anymore accidentally name love) the again the love you again i anymore, i your doesn't i again you i that bad? on love to anymore the i'll you i i mind just again again i anymore name i i to to i the and the never i
# ----
# iter 7200, loss: 46.402588
# ----
#  on you so that would knees not just because i to myself lying your i'm the the best i've to myself i would knees just to myself mind song, name i am hear into to myself do i mean i lying would knees not because had? hear time just i
# ----
# iter 7300, loss: 45.677549
# ----
#  had? one do anything change bad? anymore, again you're the time you're am lying i to love doesn't best i've the your slipped the ever feel i because the to hear you're so am we am lying just because the me lying to myself myself myself swearing mind more doesn't
# ----
# iter 7400, loss: 45.188676
# ----
#  ever (love, to myself i'm love you say never feel mean you say i've to so myself myself again myself i picture do love) love i i'm i ever lying into mind doesn't mean had? when same took do anything do am say that you say know ever doesn't doesn't
# ----
# iter 7500, loss: 44.872913
# ----
#  say and yours" i am lying that you i feel ever my my best the i know feel never mean you the had? had? best to do anything to not hear best say my to just because you had? am to to swearing i again i know i'll (love, just
# ----
# iter 7600, loss: 44.703178
# ----
#  i run anymore i because know i'll song, i i've my i you're not do not not not same doesn't i anything the accidentally i run anymore i'll i i and anything not know i'll i had? love knees love the not same you love you and i love the
# ----
# iter 7700, loss: 44.555723
# ----
#  more (love, my my just again because picture slipped when (love, your well, i say because missing you missing know just yours" i'll just because more picture because one do know because my swearing and doesn't doesn't mean mean name i more say say doesn't ever ever doesn't yours" when
# ----
# iter 7800, loss: 44.288905
# ----
#  on go love) uh we on change time just because i uh uh uh uh uh uh run change anything uh do accidentally because anymore swearing anymore, i'll i again love insecure just because doesn't i just i'd go hoping on places knees just because love) uh last last time
# ----
# iter 7900, loss: 43.968063
# ----
#  hear i'd uh not missing when i'm do my i'd i'd because picture i picture your slipped it love am yours" you am missing picture just i picture again would hear hear am hoping just because yours" hear just because your when myself when yours" i'm missing am me your
# ----
# iter 8000, loss: 43.654805
# ----
#  not i just because i i lying that doesn't just because i lying i i lying hear when i i've bad? hoping that i'd change change uh uh uh uh uh change anything and to you ever know i'll the just because am you one that hoping change i am
# ----
# iter 8100, loss: 43.372554
# ----
#  say because so best i've bad? more lying mean best took had? time bad? (love, hear you lying to more i again i i'd on feel ever mean say the know i'll i you ever say missing because ever ever you and i'd to you best when bad? to on
# ----
# iter 8200, loss: 43.050132
# ----
#  name slipped i'm to i just i lying i say say to again i know i'll mean doesn't mean song, mean i'll lying would i lying i the i feel had? am you doesn't ever you ever again i never i i know i'll you ever mean i'm swearing to
# ----
# iter 8300, loss: 42.738126
# ----
#  to again mean again i've again when not you say you makes me you mean just because yours" again my i i song, it ever just because not i say "i'm the had? i you i hear my phone because time just your doesn't i just my because i when
# ----
# iter 8400, loss: 42.659752
# ----
#  mean ever you're not same know me to i you wander you're am you're uh uh uh uh run anymore anything to myself mean mean slipped you anymore anymore time just because say would change uh uh uh love) love never the love it well, makes that not love name
# ----
# iter 8500, loss: 42.845199
# ----
#  you're my phone we anymore say to myself when you're my you're my phone am i'm on my you're my knees that i've i'm i lying go anymore, i never ever picture again hear uh love) we just because say again that hoping that i best i've to to again
# ----
# iter 8600, loss: 42.762825
# ----
#  when because mean i just because anything i'm to i you say i lying mean just because ever to would when (love, when myself you i you say i lying because just because just because doesn't mean your more i and the i'd you one just because again when (love,
# ----
# iter 8700, loss: 42.482599
# ----
#  because i yours" i'm best missing just because me took i i to when swearing you still slipped missing know am i (love, am i lying just because again when you i'm you say just because again when when phone love doesn't mean ever i say that i lying to
# ----
# iter 8800, loss: 42.123531
# ----
#  doesn't the you so say you're am your song, just the so i doesn't doesn't the again it slipped still doesn't doesn't lying i'll would you know i you one to just swearing you say hear my just because so "i'm hear just because so to hear never i insecure
# ----
# iter 8900, loss: 41.837474
# ----
#  again when my phone so go time love) still on phone well, we just because i 'round go still i love doesn't mean that i places love) love) love) love) love) love) anymore say on mind i'd love) love) anymore i've i've missing say am on name i'd phone makes
# ----
# iter 9000, loss: 41.612650
# ----
#  know i'll mean love on and and i'm because just because took you say "i'm well, know i am not and when i lying am uh uh uh uh do anything that when because best uh uh uh uh that love mean just because know again your me i'm my
# ----
# iter 9100, loss: 41.367405
# ----
#  it makes and you doesn't not the the say the never on phone off never ever feel feel makes you feel mean again knees and swearing off say bad? hear and love) anymore the yours" name makes makes makes song, the we go anymore i'm that feel had? knees your
# ----
# iter 9200, loss: 42.210561
# ----
#  i that i you doesn't you took you you i i one i you more hoping you you hoping you you you i you i change i you mean slipped that doesn't you doesn't i hoping slipped i'm you i you the that you took you anything off ever you
# ----
# iter 9300, loss: 42.474010
# ----
#  best i've you say again when am myself best i've you say to lying to to to just because doesn't lying to to myself just because (love, you're when love just because my phone i say lying to would you know just because and would go and know you on
# ----
# iter 9400, loss: 42.408751
# ----
#  change go we change and into your i'll again when because one do the into swearing i'd said change change go i ever to hear change uh love) change change change change my knees phone i mean so just to to when i swearing and to when my when go
# ----
# iter 9500, loss: 42.238471
# ----
#  had? and you say because took still swearing "i'm yours" you're still on when not and ever doesn't am i heard i not my mind doesn't my mind picture would change love) into and that not you're not hear and ever doesn't lying and you're not on into and more
# ----
# iter 9600, loss: 41.746906
# ----
#  just because ever my phone knees and the said and swearing just because me doesn't lying "i'm knees yours" knees still on my and and doesn't i'm i'm on my knees and ever yours" knees am you say "i'm know i'll never ever feel had? i'm feel you say not
# ----
# iter 9700, loss: 40.974672
# ----
#  lying would and lying you know i'll i i i just because best and still because i lying i love song, just because i again say i doesn't lying i i and am i insecure i accidentally you when that i swearing hear do would i to i i'm to
# ----
# iter 9800, loss: 40.036773
# ----
#  on love) and on anymore anymore (love, and and to phone on the just when swearing on phone you on lying run on do on myself phone my again i know the heard again again when on myself the on again on bad? just you anymore say and on i
# ----
# iter 9900, loss: 43.290927
